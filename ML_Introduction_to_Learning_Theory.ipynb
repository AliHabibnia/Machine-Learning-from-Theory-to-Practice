# %% [markdown]
# # <center><font color=navy> Machine Learning from Theory to Practice</font></center>
# ## <center><font color=navy> Introduction to Learning Theory</font> </center>
# ### <center> Ali Habibnia</center>
#
#
# <center> Assistant Professor, Department of Economics, </center>
# <center> and Division of Computational Modeling & Data Analytics at Virginia Tech</center>
#  <center> habibnia@vt.edu </center>

# %% [markdown]
# <img src="images/Life is like ML.JPG" width="600" height="800"/>

# %% [markdown]
# ### Textbooks
# ----
# Understanding Machine Learning: From Theory to Algorithms | The Elements of Statistical Learning: data mining, inference, and prediction | Pattern Recognition and Machine Learning | Deep Learning
# - | - | - | -
# ![alt](https://images-na.ssl-images-amazon.com/images/I/51tj3nARJuL._SX347_BO1,204,203,200_.jpg) | ![alt](https://images-na.ssl-images-amazon.com/images/I/41aQrQaPseL._SX331_BO1,204,203,200_.jpg) | ![alt](https://images-na.ssl-images-amazon.com/images/I/61FKyOeM7KL._SX368_BO1,204,203,200_.jpg) | ![alt](https://images-na.ssl-images-amazon.com/images/I/610HnULa0dL.jpg)
#
# The Nature of Statistical Learning Theory | Foundations of Machine Learning  | Machine Learning Yearning | Hands-On Machine Learning with Scikit-Learn and TensorFlow
# - | - | - | -
# ![alt](https://images-na.ssl-images-amazon.com/images/I/41DGQZQJh9L._SX327_BO1,204,203,200_.jpg) | ![alt](https://images-na.ssl-images-amazon.com/images/I/41fqHpSJeqL._SX367_BO1,204,203,200_.jpg) | ![alt](https://images.gr-assets.com/books/1480798569l/30741739.jpg) | ![alt](https://images-na.ssl-images-amazon.com/images/I/51%2BkYprYK1L._SX379_BO1,204,203,200_.jpg)
#
# ---------

# %% [markdown]
# * #### Today, we find ourselves at the meeting point of three technologies.
#     * HPC + Big Data + AI & ML
# <img src="images/bigdata.PNG"/>
#
# * ####  The recent success of machine learning relies heavily on the surge of big data, big models, and big computing.
#
#
# * #### Computer infrastructure both hardware and software has improved. Parallel computing, gpu, cluster computing, and cloud computing.
#
#
#
# * #### A resurgence in the field of artificial neural networks --> Deep learning (Algorithms with many parameters and hyperparameters)

# %% [markdown]
# ## Optimization is at the heart of almost all machine learning algorithms
#
# * #### Pillars of Machine Learning: Linear algebra, probability analysis, and neumerical optimization
#
# Machine Learning has been an interesting topic for a lot of people since the 60s. However many people are afraid to start learning ML, mostly because it requires some knowledge of linear algebra and calculus. The course as you know is on Machine Learning and in this notebook we are going to let you go of the fear and see how with little effort practical models can be made to solve some real-world applications.
#
# * #### Building accurate models is a complex and challenging task.
#
#
# <img src="images/model.PNG" />
#
#
#
#
# ### Econometrics vs. Machine Learning
#
# #### Goal of econometrics
#
# * #### "the goal of econometrics is to find $\hat\theta$ where here we mean $\hat\theta$ to be the causal impact of X on y
#
# * #### The primary statistical concern of econometrics is sampling error. In other words, the goal is to quantify the uncertainty around $\hat\theta$ due to randomness in the sampling of the population.
#
# * #### The goal is to make counterfactual predictions.
#
#         What would happen to Amazon's profits if it changed its website layout?
#
# We don't get to observe the world under these alternative policies, so we can't simply find the answers in the data. Knowing the counterfactual requires being able to measure a causal effect. Being able to measure a causal effect requires making assumptions. That's what economics is all about!
#
#
# #### Goal of machine learning
#
# * #### In contrast, the goal of machine learning is to come up with the best possible out-of-sample prediction.
#
# * #### We refer to this as the primary concern of machine learning being "$\hat y$"
#
# * #### The goal is to make sure that the best prediction is had by tuning and validating many different kinds of models. This is what cross-validation is all about, and it is what machine learning practitioners obsess about.

# %% [markdown]
# ## Definition of Machine Learning

# %% [markdown]
#     Machine Learning is a field of computer science that gives computers the ability to learn without being explicitly programmed. (Wikipedia)
#
# Machine learning was born during the early development of artificial intelligence and pattern recognition. Like all the other technologies it grew into the industry with the help of the businesses. There is one widely used formal definition of machine learning algorithms:
#
#     “A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P, improves with experience E.” — Tom. M. Mitchell
#
# The definition states that our program has to learn from our data and should improve its performance. As a classical example, if we want to predict the house prices, first we can feed our algorithm with the data like current prices according to the area of a house, # of bedrooms etc. From the data, the algorithm learns and improves its guesses by reducing the errors for predictions. We can measure the performance by running the algorithm using a new input data with known results and take a look at the error rate. Our aim in here will be reducing the error rate.

# %% [markdown]
# ## Types of Machine Learning Problems and Tasks

# %% [markdown]
# ### Supervised Learning

# %% [markdown]
# This type of ML algorithms works with the teacher model. It means that we have a dataset with inputs and output values; that is labeled data. We define a method to get known outputs for the inputs we have. As we improve our method by using all input-output pairs (this is called training), we can predict output values for new input data. This is called supervised learning. We learn the model using the *training data* and we test the model with unseen *test data*. So, we work both with input and output data. An example of supervised learning is predicting house prices. Another is to tell what digit or animal or picture is in a picture.
#
# Examples:
#
# - Regression (y is Continuous, i.e. linear regression)
# - Classification ( y is binary or multiclass, i.e. logistic regression)

# %% [markdown]
# ### Unsupervised Learning

# %% [markdown]
# Unsupervised learning algorithms are used when we have only input data and no corresponding output values. There are no correct answers, therefore no teacher. These algorithms will be able to find hidden structure or relationship between different inputs. One of the best use cases for unsupervised learning algorithms is clustering problems.
#
# Example:
#
# - Clustering (i.e. K-means)
# - Dimensionality reduction (i.e. PCA)

# %% [markdown]
# ### Semi-Supervised Learning

# %% [markdown]
# These algorithms are used where there is a huge amount of input data but only small amount of output (labeled) data. These problems sit in the middle of supervised and unsupervised learning. Therefore, supervised and unsupervised learning techniques are used together. One of the best examples for this is identifying objects in photos. Some photos are labeled as apples or lions but most of them are not labeled.

# %% [markdown]
# ### Reinforcement Learning

# %% [markdown]
# Reinforcement Learning is influenced by behavioral psychology with a rewarding system. We can think this is like playing with a dog. We have a dog (terminologically called an *agent*) and we have a park (*environment*) where he can do whatever he wants. Whenever dog gets back to you with a stick, you *reward* him with a food. After a while, the dog will start to have better approaches to find other sticks around. So, he will learn from the reward system. This approach in dog’s head is called reinforcement learning. We have an agent, environment, and reward. The difference between supervised learning is in the output data. In reinforcement learning, when the dog is walking around, he doesn’t know he will get a reward or not. He may never get a reward at all. But whenever he finds, he has learned to win. So, output data may come sometime later. In supervised learning, we know the output beforehand and make predictions by looking to them.

# %% [markdown]
# <img src="images/types.PNG"/>

# %% [markdown]
# ## Showcase - Credit Card Fraud Detection

# %% [markdown]
# In recent decades, we have been on a express train to a cashless society. According to the World Payments Report, in 2016 total non-cash transactions increased by 10.1% from 2015 for a total of 482.6 billion transactions!
#
# Despite this exciting news, on the flip-side fraudulent transactions are on the rise as well. **Fraud detection** is one of the top priorities for banks and financial institutions. For years, fraudsters would simply take numbers from credit or debit cards and print them onto blank plastic cards. In 2015, Visa and Mastercard mandated that banks and merchants implement chip card technology, which made it possible for merchants to start requesting a PIN for each transaction.
#
# In 2017, the worldwide losses in card fraud related cases reached 22.8 billion dollars. Nevertheless, it is estimated to get worse in the following years, reaching 32.96 billion dollars by 2021.
#
# In addition to the implementation of chip card technology, companies have been investing massive amounts in other technologies for detecting fraudulent transactions. That is where Machine Learning comes to the scene.
#
#
#
# <center><img src="https://miro.medium.com/max/1588/1*d63BwvXOLljziBz7i6brJQ.png" width="750" alt="timeline"></center>

# %% [markdown]
# # Classification Problem

# %% [markdown]
# Fraud detection can be framed as a classification problems -- predicting a discrete class label output given a data observation. Examples of classification problems that can be thought of are Spam Detectors, Quality Control, Recommender Systems and Loan Default Prediction.

# %% [markdown]
# Formulating the problem of credit card payment fraud detection as a classification problem, we are in search of a proper ML model that can classify transactions as either **legit** or **fraudulent**, based on some sample features such as transaction details like amount, merchant, location, time and others.

# %% [markdown]
# # Imbalanced Data

# %% [markdown]
# The main challenge when it comes to modeling fraud detection as a classification problem comes from the fact that in real world data, the **majority of transactions is not fraudulent**. This problem is known as **imbalanced data**.

# %% [markdown]
# Fraud detection problems are known for being (naturally) extremely imbalanced.

# %% [markdown]
# # Dataset

# %% [markdown]
# Here, we will use the credit [card fraud detection dataset](https://www.kaggle.com/mlg-ulb/creditcardfraud) from Kaggle, to identify fraud cases.
#
# The dataset contains about 285,000 samples and 31 columns. Excluding the class column (target variable), we have 30 features including **Time** and **Amount**. The other 28 columns, labeled **V1-V28** have been transformed (probably using what seems to be PCA) in order to protect user identities.
#
# The dataset only represents 2 days of transactions, made by European cardholders.

# %% [markdown]
# Let's import necessary libraries and load the dataset.

# %%
pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.0/2.0 MB 7.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -q -U tensorflow-gpu

# !pip install https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.8.0-py3-none-any.whl
# Out:
# ...
#   Using cached https://storage.googleapis.com/tensorflow/mac/cpu/tensorflow-1.8.0-py3-none-any.whl (46.5 MB)
# ...

# %%
# !pip install -q -U keras

# %%
# !pip install -q matplotlib
# !pip install plotly

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U numpy
# !pip install -U tensorflow
# Out:
# ...
#      ---------------------------------------- 14.6/14.6 MB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.0
#     Uninstalling numpy-1.22.0:
#       Successfully uninstalled numpy-1.22.0
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.3 which is incompatible.
# ...
#      -------------------------------------- 455.9/455.9 MB 4.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.2/14.2 MB 12.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.6/2.6 MB 9.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.9/5.9 MB 11.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
plt.style.use('ggplot')

#import keras
#np.random.seed(2)

#from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %%
data = pd.read_csv('https://github.com/nsethi31/Kaggle-Data-Credit-Card-Fraud-Detection/raw/master/creditcard.csv')

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# Inspecting data reveals that we do not need to worry about missing values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# Let's quickly look at some summary statistics on the features.

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  1.758743e-12  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# Most of predictors have been anonymized, and although informative analysis could be made on them, let's only focus on non-anonymized predictors: time and amount of the transaction

# %% [markdown]
# The mean value of all transactions is 88.35 dollars while the largest transaction recorded in this data set amounts to 25,691.16 dollars.
#
# As you might have guessed based on the mean and maximum, the distribution of the monetary value of all transactions is heavily right-skewed. The vast majority of transactions are relatively small and only a tiny fraction of transactions comes even close to the maximum.

# %%
plt.figure(figsize=(13, 6))
plt.title('Distribution of transaction value (Amount)')
sns.distplot(data.Amount);

# %%
plt.figure(figsize=(13, 6))
plt.title('Distribution of Time')
sns.distplot(data.Time);

# %% [markdown]
# We may gain more insight if we plotted such data separately for each class

# %%
class_0 = data.loc[data['Class'] == 0]["Time"]
class_1 = data.loc[data['Class'] == 1]["Time"]
hist_data = [class_0, class_1]
group_labels = ['Not Fraud', 'Fraud']

fig = ff.create_distplot(hist_data, group_labels, show_hist=False, show_rug=False)
fig['layout'].update(title='Credit Card Transactions Time Density Plot', xaxis=dict(title='Time [s]'))
iplot(fig, filename='dist_only')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="08e7635a-e8cc-4715-8eea-5fe673abf58e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08e7635a-e8cc-4715-8eea-5fe673abf58e")) {
#                     Plotly.newPlot(
#                         '08e7635a-e8cc-4715-8eea-5fe673abf58e',
# ...

# %% [markdown]
# And similarly for transaction amount:

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="Class", y="Amount", hue="Class", data=data, palette="PRGn", showfliers=True)
s = sns.boxplot(ax = ax2, x="Class", y="Amount", hue="Class", data=data, palette="PRGn", showfliers=False)
plt.show();

# %% [markdown]
# You can see the imbalanced data problem we mentioned below:

# %%
counts = data.Class.value_counts()
normal = counts[0]
fraudulent = counts[1]
perc_normal = (normal/(normal+fraudulent))*100
perc_fraudulent = (fraudulent/(normal+fraudulent))*100
print('There were {} non-fraudulent transactions ({:.3f}%) and {} fraudulent transactions ({:.3f}%).'.format(normal, perc_normal, fraudulent, perc_fraudulent))
# Out:
# There were 284315 non-fraudulent transactions (99.827%) and 492 fraudulent transactions (0.173%).

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=counts.index, y=counts)
plt.title('Count of Fraudulent vs. Non-Fraudulent Transactions')
plt.ylabel('Count')
plt.xlabel('Class (0:Non-Fraudulent, 1:Fraudulent)');

# %% [markdown]
# One implication of this imbalance, regardless of the difficulty to build proper models on such datasets, is the assessment of the model. If we replace our model with a single line of code that returns zero (predicts non-fraudulent) for any sample, it achieves the high accuracy rate of $99.827\%$. Therefore, accuracy is not a proper measure of performance for such problem.

# %% [markdown]
# Next, it would be interesting to know if there are any significant correlations between our predictors, especially with regards to our class variable. One of the most visually appealing ways to determine that is by using a heatmap.

# %%
corr = data.corr()
plt.figure(figsize=(10, 8))
heat = sns.heatmap(data=corr)
plt.title('Heatmap of Correlation');

# %% [markdown]
# First off, you can see that the anonymized predictors are not correlated with each other. This verifies that they have probably used PCA on these features.
#
# Moreover, some of our predictors do seem to be correlated with the class variable. There seem to be relatively little significant correlations for such a big number of variables. This can probably be attributed to two factors:
#
# * The data was prepared using a PCA, therefore our predictors are principal components.
# * The significant class-imbalance might be distorting the importance of certain correlations with regards to our class variable.

# %% [markdown]
# This is one other way of seeing the correlations:

# %%
data.corrwith(data.Class).plot.bar(
        figsize = (15, 10), title = "Correlation with class", fontsize = 15,
        rot = 45, grid = True);

# %% [markdown]
# Drawing Features density plot can also be very informative:

# %%
var = data.columns.values

i = 0
t0 = data.loc[data['Class'] == 0]
t1 = data.loc[data['Class'] == 1]

sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(8,4,figsize=(16,28))

for feature in var:
    i += 1
    plt.subplot(8,4,i)
    sns.kdeplot(t0[feature], bw=0.5,label="Class = 0")
    sns.kdeplot(t1[feature], bw=0.5,label="Class = 1")
    plt.xlabel(feature, fontsize=12)
    locs, labels = plt.xticks()
    plt.tick_params(axis='both', which='major', labelsize=12)
plt.show();

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
data['normalizedAmount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1,1))
data = data.drop(['Amount'], axis=1)

# %%
data = data.drop(['Time'],axis=1)
data.head()
# Out:
#          V1        V2        V3  ...       V28  Class  normalizedAmount
# 0 -1.359807 -0.072781  2.536347  ... -0.021053      0          0.244964
# 1  1.191857  0.266151  0.166480  ...  0.014724      0         -0.342475
# 2 -1.358354 -1.340163  1.773209  ... -0.059752      0          1.160686
# 3 -0.966272 -0.185226  1.792993  ...  0.061458      0          0.140534
# 4 -1.158233  0.877737  1.548718  ...  0.215153      0         -0.073403
#
# [5 rows x 30 columns]

# %% [markdown]
# # Predictive Modeling

# %%
X = data.iloc[:, data.columns != 'Class']
y = data.iloc[:, data.columns == 'Class']

# %% [markdown]
# ## Split to train and test sets

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=0)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(solver='lbfgs')
classifier.fit(X_train, y_train.values.ravel())

# Predicting Test Set
y_pred_lr = classifier.predict(X_test)

# %% [markdown]
# ### Confusion matrix

# %% [markdown]
# **Confusion matrix** is a performance measurement for machine learning classification problem where output can be two or more classes. It is a table with 4 different combinations of predicted and actual values.
#
# <center><img src="https://miro.medium.com/max/712/1*g5zpskPaxO8uSl0OWT4NTQ.png" width="350" alt="timeline"></center>

# %%
from sklearn.metrics import confusion_matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)
cm_lr
# Out:
# array([[85284,    12],
#        [   56,    91]])

# %%
df_cm = pd.DataFrame(cm_lr, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10, 7))
sns.set(font_scale=1.0)
sns.heatmap(df_cm, cmap="Blues", annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred_lr))
# Out:
# Test Data Accuracy: 0.9992

# %% [markdown]
# ### More performance metrics:

# %% [markdown]
# $$F 1 \text { score }=\frac{2 * \text { precision*recall }}{\text { precision trecall }}$$

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.88      0.62      0.73       147
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.81      0.86     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# ## Feed-forward Neural Network

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units =15 , kernel_initializer = 'uniform', activation = 'relu', input_dim = 29))

# Adding the second hidden layer
classifier.add(Dense(units = 15, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 32, epochs = 20)
# classifier.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/20
# 199364/199364 [==============================] - 8s 40us/step - loss: 0.0155 - accuracy: 0.9987
# Epoch 2/20
# 199364/199364 [==============================] - 8s 39us/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 3/20
# 199364/199364 [==============================] - 8s 39us/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 4/20
# 199364/199364 [==============================] - 8s 40us/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 5/20
# 199364/199364 [==============================] - 8s 40us/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 6/20
# 199364/199364 [==============================] - 8s 40us/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 7/20
# 199364/199364 [==============================] - 8s 39us/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 8/20
# 199364/199364 [==============================] - 8s 39us/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 9/20
# 199364/199364 [==============================] - 8s 40us/step - loss: 0.0023 - accuracy: 0.9995
# ...

# %%
# Predicting the Test set results
y_pred_nn = classifier.predict(X_test)
y_pred_nn = (y_pred_nn > 0.5)

# %%
score = classifier.evaluate(X_test, y_test)
score
# Out:
# 85443/85443 [==============================] - 2s 19us/step
# [0.0035470559907884278, 0.9993445873260498]

# %%
from sklearn.metrics import confusion_matrix
cm_nn = confusion_matrix(y_test, y_pred_nn)
cm_nn
# Out:
# array([[85274,    22],
#        [   34,   113]])

# %%
df_cm = pd.DataFrame(cm_nn, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10, 7))
sns.set(font_scale=1.0)
sns.heatmap(df_cm, cmap="Blues", annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred_nn))
# Out:
# Test Data Accuracy: 0.9993

# %% [markdown]
# Performance metrics

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_nn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.84      0.77      0.80       147
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.88      0.90     85443
# weighted avg       1.00      1.00      1.00     85443
